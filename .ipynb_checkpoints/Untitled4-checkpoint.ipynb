# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tb = pd.read_csv('brasileirao-seriea.txt', seq=" " , header=None, names=["A", "B"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5843fc49e68d> in <module>
# ----> 1 tb = pd.read_csv('brasileirao-seriea.txt', seq='' , header=None, names=["A", "B"])
#
# TypeError: parser_f() got an unexpected keyword argument 'seq'

# %%
tb
# Out:
#                                          A          B
# 0                                 Rodada 1        NaN
# 1                                     [Sáb   13/Maio]
# 2      Corinthians     1 - 1   Chapecoense        NaN
# 3                                     [Dom   14/Maio]
# 4           Fluminense      3 - 2   Santos        NaN
# 5    Palmeiras       4 - 0   Vasco da Gama        NaN
# 6        Cruzeiro        1 - 0   São Paulo        NaN
# 7      Bahia           6 - 2   Atlético PR        NaN
# 8            Ponte Preta     4 - 0   Sport        NaN
# 9          Avaí            0 - 0   Vitória        NaN
# 10        Grêmio          2 - 0   Botafogo        NaN
# 11                                    [Seg   15/Maio]
# 12     Coritiba        4 - 1   Atlético GO        NaN
# 13                                Rodada 2        NaN
# 14                                    [Sáb   20/Maio]
# 15        Santos          1 - 0   Coritiba        NaN
# ...
