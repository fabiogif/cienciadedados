# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
xlsx = pd.ExcelFile('ATU_BRASIL_REGIOES_UFS_2018.xlsx')
df = pd.read_excel(xlsx)

# %%
df.dropna()
# Out:
#               Ano Unidade Geográfica Localização Dependência Administrativa  \
# 2    NU_ANO_CENSO              SG_UF    TIPOLOCA                   Dependad
# 3            2018             Brasil       Total                      Total
# 4            2018             Brasil      Urbana                      Total
# 5            2018             Brasil       Rural                      Total
# 6            2018             Brasil       Total                    Federal
# 7            2018             Brasil      Urbana                    Federal
# 8            2018             Brasil       Rural                    Federal
# 9            2018             Brasil       Total                   Estadual
# 10           2018             Brasil      Urbana                   Estadual
# 11           2018             Brasil       Rural                   Estadual
# 12           2018             Brasil       Total                  Municipal
# ...
