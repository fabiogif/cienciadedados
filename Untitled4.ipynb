# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tb = pd.read_excel('campeonato-brasileiro-full.xlsx')

# %%
data = pd.DataFrame(tb)

# %%
data.head()
# Out:
#   Horario      Dia        Data     Clube 1     Clube 2    Vencedor     Rodada  \
# 0   16h00   Sábado  29/07/2000       Vasco       Sport       Sport  1ª Rodada
# 1   16h00   Sábado  29/07/2000     Vitória   Palmeiras     Vitória  1ª Rodada
# 2   16h00   Sábado  29/07/2000  Fluminense       Bahia  Fluminense  1ª Rodada
# 3   16h00  Domingo  30/07/2000  América-MG        Gama        Gama  1ª Rodada
# 4   16h00  Domingo  30/07/2000     Guarani  Santa Cruz           -  1ª Rodada
#
#             Arena  p1  p2 C1 Estado C2 Estado Vencedor Estado
# 0    São Januário   0   2        RJ        PE              PE
# 1        Barradão   4   1        ES        SP              ES
# 2        Maracanã   2   0        RJ        BH              RJ
# 3   Independência   0   1        MG        DF              DF
# 4  Brinco de Ouro   0   0        SP        PE          Empate

# %%
(data['Rodada'] == "1ª Rodada").value_counts()
# Out:
# False    6988
# True      191
# Name: Rodada, dtype: int64

# %%
vt = data[data['Arena'] == 'Barradão']['Vencedor'].value_counts()

# %%
df = pd.DataFrame(vt)
df
# Out:
#                Vencedor
# Vitória             100
# -                    52
# São Paulo             6
# Cruzeiro              5
# Flamengo              4
# Santos                4
# Fluminense            3
# Atlético-PR           3
# Botafogo              2
# Atlético-MG           2
# Avaí                  2
# Corinthians           2
# Grêmio                2
# Chapecoense           2
# Ponte Preta           2
# Palmeiras             2
# Paraná                1
# Juventude             1
# Guarani               1
# Internacional         1
# Figueirense           1
# São Caetano           1
# Criciúma              1
# Goiás                 1
# Vasco                 1
# Sport                 1

# %%
plt.figure(figsize= (200,200))

sns.countplot(x='Vencedor', data=data, palette='viridis' )

# %%
vencedor =   data['Vencedor Estado'].value_counts()


#(data['Rodada'] == "1ª Rodada")
# Out:
# Empate    1832
# SP        1522
# RJ         921
# RS         635
# MG         594
# PR         544
# SC         313
# GO         238
# PE         197
# ES         143
# BH          99
# CE          56
# PA          50
# DF          31
# RN           4
# Name: Vencedor Estado, dtype: int64

# %%
#plt.figure(figsize= (12,6))
#sns.countplot(x='Vencedor Estado', data=vt, palette='viridis' )

# %%
# Out:
# PE
# ES
# RJ
# DF
# Empate
# PR
# Empate
# GO
# Empate
# Empate
# DF
# SP
# BH
# SP
# GO
# RJ
# Empate
# Empate
# RJ
# SP
# GO
# Empate
# Empate
# SP
# Empate
# SP
# RJ
# PR
# Empate
# Empate
# RJ
# PE
# GO
# Empate
# Empate
# RJ
# Empate
# PR
# DF
# SP
# SP
# SP
# ES
# SP
# RS
# Empate
# RJ
# Empate
# ES
# GO
# Empate
# Empate
# SP
# SP
# BH
# Empate
# Empate
# RJ
# MG
# Empate
# MG
# RS
# Empate
# Empate
# PR
# RJ
# Empate
# Empate
# Empate
# Empate
# SP
# Empate
# Empate
# MG
# Empate
# RJ
# RJ
# PR
# MG
# RJ
# SP
# RS
# BH
# Empate
# SP
# Empate
# PE
# SP
# SP
# RS
# ES
# PR
# Empate
# RJ
# Empate
# RS
# ES
# Empate
# MG
# RJ
# SP
# Empate
# Empate
# Empate
# RS
# RJ
# Empate
# MG
# MG
# RS
# SP
# SP
# SP
# Empate
# GO
# Empate
# MG
# PR
# Empate
# BH
# SP
# RS
# Empate
# SP
# RJ
# PE
# DF
# ES
# MG
# RJ
# RS
# Empate
# Empate
# Empate
# RS
# RJ
# MG
# SP
# Empate
# Empate
# Empate
# Empate
# BH
# SP
# SP
# DF
# PE
# RJ
# RJ
# Empate
# SP
# RS
# SP
# GO
# SP
# SP
# SP
# RJ
# MG
# ...

# %%
data.describe()
# Out:
#                 p1           p2
# count  7179.000000  7179.000000
# mean      1.619585     1.072991
# std       1.257471     1.049470
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     2.000000
# max       7.000000     7.000000
